# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/top-all-time-nba-paint-finishers-1997-2023?scriptVersionId=197846321" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
sht = pd.read_csv('/kaggle/input/Player Shooting.csv')
tot = pd.read_csv('/kaggle/input/Player Totals.csv')
pbp = pd.read_csv('/kaggle/input/Player Play By Play.csv')

print(sht.head())
print(tot.head())
print(pbp.head())
print(sht.columns)
print(tot.columns)
print(pbp.columns)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/Advanced.csv
# /kaggle/input/Player Season Info.csv
# /kaggle/input/Player Career Info.csv
# /kaggle/input/Player Shooting.csv
# /kaggle/input/Opponent Stats Per Game.csv
# /kaggle/input/Player Totals.csv
# /kaggle/input/Opponent Stats Per 100 Poss.csv
# /kaggle/input/Per 100 Poss.csv
# /kaggle/input/Team Summaries.csv
# /kaggle/input/Player Per Game.csv
# /kaggle/input/All-Star Selections.csv
# /kaggle/input/End of Season Teams (Voting).csv
# /kaggle/input/Player Play By Play.csv
# /kaggle/input/End of Season Teams.csv
# /kaggle/input/Team Stats Per 100 Poss.csv
# /kaggle/input/Per 36 Minutes.csv
# /kaggle/input/Opponent Totals.csv
# /kaggle/input/Team Abbrev.csv
# /kaggle/input/Player Award Shares.csv
# /kaggle/input/Team Totals.csv
# /kaggle/input/Team Stats Per Game.csv
#    seas_id  season  player_id         player  birth_year pos  age  experience  \
# 0    31136    2024       5025     A.J. Green         NaN  SG   24           2
# 1    31137    2024       5026    A.J. Lawson         NaN  SG   23           2
# 2    31138    2024       5027     AJ Griffin         NaN  SF   20           2
# 3    31139    2024       4219   Aaron Gordon         NaN  PF   28          10
# 4    31140    2024       4582  Aaron Holiday         NaN  PG   27           6
#
#     lg   tm  ...  fg_percent_from_x16_3p_range  fg_percent_from_x3p_range  \
# 0  NBA  MIL  ...                         0.500                      0.408
# 1  NBA  DAL  ...                         0.500                      0.260
# 2  NBA  ATL  ...                         0.250                      0.256
# 3  NBA  DEN  ...                         0.417                      0.290
# 4  NBA  HOU  ...                         0.350                      0.387
#
#    percent_assisted_x2p_fg  percent_assisted_x3p_fg  percent_dunks_of_fga  \
# 0                    0.857                    0.942                 0.000
# 1                    0.610                    1.000                 0.107
# 2                    0.750                    0.800                 0.016
# 3                    0.642                    0.850                 0.256
# 4                    0.255                    0.810                 0.005
#
#    num_of_dunks  percent_corner_3s_of_3pa  corner_3_point_percent  \
# 0             0                     0.225                   0.447
# 1            12                     0.640                   0.250
# 2             1                     0.205                   0.250
# 3           171                     0.391                   0.352
# 4             2                     0.212                   0.478
#
#    num_heaves_attempted  num_heaves_made
# 0                     0                0
# 1                     0                0
# 2                     0                0
# 3                     1                0
# 4                     1                0
#
# [5 rows x 34 columns]
#    seas_id  season  player_id         player  birth_year pos   age  \
# 0    31136    2024       5025     A.J. Green         NaN  SG  24.0
# 1    31137    2024       5026    A.J. Lawson         NaN  SG  23.0
# 2    31138    2024       5027     AJ Griffin         NaN  SF  20.0
# 3    31139    2024       4219   Aaron Gordon         NaN  PF  28.0
# 4    31140    2024       4582  Aaron Holiday         NaN  PG  27.0
#
#    experience   lg   tm  ...  ft_percent    orb    drb    trb  ast   stl  \
# 0           2  NBA  MIL  ...       0.895    9.0   55.0   64.0   30   9.0
# 1           2  NBA  DAL  ...       0.652   14.0   36.0   50.0   20  10.0
# 2           2  NBA  ATL  ...       1.000    2.0   16.0   18.0    5   1.0
# 3          10  NBA  DEN  ...       0.658  174.0  297.0  471.0  259  56.0
# 4           6  NBA  HOU  ...       0.921   23.0  100.0  123.0  140  42.0
#
#     blk    tov   pf   pts
# 0   4.0   12.0   49   252
# 1   3.0   14.0   22   136
# 2   2.0    8.0    6    48
# 3  45.0  105.0  142  1013
# 4   6.0   53.0  125   514
#
# [5 rows x 35 columns]
#    seas_id  season  player_id         player  birth_year pos  age  experience  \
# 0    31136    2024       5025     A.J. Green         NaN  SG   24           2
# 1    31137    2024       5026    A.J. Lawson         NaN  SG   23           2
# 2    31138    2024       5027     AJ Griffin         NaN  SF   20           2
# 3    31139    2024       4219   Aaron Gordon         NaN  PF   28          10
# 4    31140    2024       4582  Aaron Holiday         NaN  PG   27           6
#
#     lg   tm  ...  net_plus_minus_per_100_poss  bad_pass_turnover  \
# 0  NBA  MIL  ...                          2.3                  7
# 1  NBA  DAL  ...                          0.6                  7
# 2  NBA  ATL  ...                        -12.0                  4
# 3  NBA  DEN  ...                          8.5                 44
# 4  NBA  HOU  ...                          4.4                 28
#
#    lost_ball_turnover  shooting_foul_committed  offensive_foul_committed  \
# 0                   3                       24                         0
# 1                   2                       16                         1
# 2                   3                        3                         0
# 3                  29                       87                        20
# 4                  14                       59                         3
#
#    shooting_foul_drawn  offensive_foul_drawn  points_generated_by_assists  \
# 0                    4                   8.0                           72
# 1                   12                   0.0                           51
# 2                    1                   0.0                           13
# 3                  140                   7.0                          630
# 4                   22                  14.0                          350
#
#    and1  fga_blocked
# 0     2            3
# 1     2            8
# 2     0            3
# 3    41           57
# 4     5           20
#
# [5 rows x 28 columns]
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'mp', 'fg_percent', 'avg_dist_fga',
#        'percent_fga_from_x2p_range', 'percent_fga_from_x0_3_range',
#        'percent_fga_from_x3_10_range', 'percent_fga_from_x10_16_range',
#        'percent_fga_from_x16_3p_range', 'percent_fga_from_x3p_range',
#        'fg_percent_from_x2p_range', 'fg_percent_from_x0_3_range',
#        'fg_percent_from_x3_10_range', 'fg_percent_from_x10_16_range',
#        'fg_percent_from_x16_3p_range', 'fg_percent_from_x3p_range',
#        'percent_assisted_x2p_fg', 'percent_assisted_x3p_fg',
#        'percent_dunks_of_fga', 'num_of_dunks', 'percent_corner_3s_of_3pa',
#        'corner_3_point_percent', 'num_heaves_attempted', 'num_heaves_made'],
#       dtype='object')
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'gs', 'mp', 'fg', 'fga', 'fg_percent',
#        'x3p', 'x3pa', 'x3p_percent', 'x2p', 'x2pa', 'x2p_percent',
#        'e_fg_percent', 'ft', 'fta', 'ft_percent', 'orb', 'drb', 'trb', 'ast',
#        'stl', 'blk', 'tov', 'pf', 'pts'],
#       dtype='object')
# Index(['seas_id', 'season', 'player_id', 'player', 'birth_year', 'pos', 'age',
#        'experience', 'lg', 'tm', 'g', 'mp', 'pg_percent', 'sg_percent',
#        'sf_percent', 'pf_percent', 'c_percent',
#        'on_court_plus_minus_per_100_poss', 'net_plus_minus_per_100_poss',
#        'bad_pass_turnover', 'lost_ball_turnover', 'shooting_foul_committed',
#        'offensive_foul_committed', 'shooting_foul_drawn',
#        'offensive_foul_drawn', 'points_generated_by_assists', 'and1',
#        'fga_blocked'],
#       dtype='object')

# %%
df1 = sht[['seas_id', 'player', 'pos', 'tm', 'season', 'mp', 'avg_dist_fga', 'percent_fga_from_x0_3_range', 'percent_fga_from_x3_10_range', 'fg_percent_from_x0_3_range', 'fg_percent_from_x3_10_range', 'num_of_dunks']]
df2 = tot[['seas_id', 'fga']]
df3 = pbp[['seas_id', 'offensive_foul_committed', 'and1', 'shooting_foul_drawn', 'fga_blocked']]

merge = df1.merge(df2, on='seas_id').merge(df3, on='seas_id')
merge.head()
# Out:
#    seas_id         player pos   tm  season    mp  avg_dist_fga  \
# 0    31136     A.J. Green  SG  MIL    2024   614          24.1
# 1    31137    A.J. Lawson  SG  DAL    2024   311          13.7
# 2    31138     AJ Griffin  SF  ATL    2024   171          19.5
# 3    31139   Aaron Gordon  PF  DEN    2024  2297           7.4
# 4    31140  Aaron Holiday  PG  HOU    2024  1269          17.3
#
#    percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 0                        0.026                         0.020
# 1                        0.355                         0.190
# 2                        0.048                         0.194
# 3                        0.554                         0.183
# 4                        0.122                         0.170
#
#    fg_percent_from_x0_3_range  fg_percent_from_x3_10_range  num_of_dunks  fga  \
# 0                       1.000                        0.250             0  196
# 1                       0.791                        0.217            12  121
# 2                       0.667                        0.250             1   62
# 3                       0.738                        0.382           171  716
# 4                       0.647                        0.437             2  417
#
#    offensive_foul_committed  and1  shooting_foul_drawn  fga_blocked
# 0                         0     2                    4            3
# 1                         1     2                   12            8
# 2                         0     0                    1            3
# 3                        20    41                  140           57
# 4                         3     5                   22           20

# %%
merge['paint_fga'] = merge['fga'] * (merge['percent_fga_from_x0_3_range'] + merge['percent_fga_from_x3_10_range'])
merge['paint_fga_no_dunk'] = merge['paint_fga'] - merge['num_of_dunks']
merge['paint_fg%'] = merge['fg_percent_from_x0_3_range'] * merge['fg_percent_from_x3_10_range']

merge.head()
# Out:
#    seas_id         player pos   tm  season    mp  avg_dist_fga  \
# 0    31136     A.J. Green  SG  MIL    2024   614          24.1
# 1    31137    A.J. Lawson  SG  DAL    2024   311          13.7
# 2    31138     AJ Griffin  SF  ATL    2024   171          19.5
# 3    31139   Aaron Gordon  PF  DEN    2024  2297           7.4
# 4    31140  Aaron Holiday  PG  HOU    2024  1269          17.3
#
#    percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 0                        0.026                         0.020
# 1                        0.355                         0.190
# 2                        0.048                         0.194
# 3                        0.554                         0.183
# 4                        0.122                         0.170
#
#    fg_percent_from_x0_3_range  fg_percent_from_x3_10_range  num_of_dunks  fga  \
# 0                       1.000                        0.250             0  196
# 1                       0.791                        0.217            12  121
# 2                       0.667                        0.250             1   62
# 3                       0.738                        0.382           171  716
# 4                       0.647                        0.437             2  417
#
#    offensive_foul_committed  and1  shooting_foul_drawn  fga_blocked  \
# 0                         0     2                    4            3
# 1                         1     2                   12            8
# 2                         0     0                    1            3
# 3                        20    41                  140           57
# 4                         3     5                   22           20
#
#    paint_fga  paint_fga_no_dunk  paint_fg%
# 0      9.016              9.016   0.250000
# 1     65.945             53.945   0.171647
# 2     15.004             14.004   0.166750
# 3    527.692            356.692   0.281916
# 4    121.764            119.764   0.282739

# %%
merge['paint_score'] = (merge['paint_fga_no_dunk'] * 1.75) + (merge['paint_fg%'] * 3.5) + (merge['and1'] * 3) + (merge['offensive_foul_committed'] * -3) + (merge['shooting_foul_drawn'] * 1.25) + (merge['num_of_dunks'] * -2.5)

sort = merge.sort_values(by='paint_score', ascending=False)

sort.head(25)
# Out:
#        seas_id            player pos   tm  season    mp  avg_dist_fga  \
# 15089    17142  Shaquille O'Neal   C  LAL    2000  3163           5.8
# 734      31870   Zion Williamson  PF  NOP    2024  2207           4.0
# 14582    17668  Shaquille O'Neal   C  LAL    2001  2924           4.7
# 15693    15689    Antoine Walker  PF  BOS    1998  3268          10.3
# 9712     22731     Zach Randolph  PF  MEM    2010  3051           7.5
# 11421    19913     Allen Iverson  PG  PHI    2006  3103          11.4
# 14691    16744    Antoine Walker  PF  BOS    2000  3003           9.6
# 536      31672      Nikola Jokić   C  DEN    2024  2737           9.7
# 3872     27871      James Harden  PG  HOU    2019  2867          16.4
# 10307    20989      Al Jefferson   C  MIN    2008  2919           6.9
# 11366    20940        Tim Duncan   C  SAS    2007  2726           6.6
# 14072    18196        Tim Duncan  PF  SAS    2002  3329           7.6
# 2014     30247      Nikola Jokić   C  DEN    2022  2476          10.2
# 14141    17227    Antawn Jamison  SF  GSW    2001  3394          11.4
# 11983    19327     Allen Iverson  PG  PHI    2005  3174          12.2
# 10311    20993     Allen Iverson  SG  DEN    2008  3424          11.8
# 9133     23356     Zach Randolph  PF  MEM    2011  2724           7.3
# 16425    15300       Gary Payton  PG  SEA    1997  3213          11.8
# 2929     29645   Zion Williamson  PF  NOP    2021  2026           3.4
# 12009    19353    Antoine Walker  PF  TOT    2005  2955           9.6
# 13132    19306     Zach Randolph  PF  POR    2004  3067           7.7
# 14838    16891       Elton Brand  PF  CHI    2000  2999           8.1
# 16244    15119    Antoine Walker  PF  BOS    1997  2970          10.5
# 293      31429     Jalen Brunson  PG  NYK    2024  2726          14.3
# 6992     24698       Greg Monroe  PF  DET    2014  2690           5.0
#
#        percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 15089                        0.402                         0.499
# 734                          0.547                         0.404
# 14582                        0.429                         0.452
# 15693                        0.347                         0.279
# 9712                         0.451                         0.226
# 11421                        0.295                         0.130
# 14691                        0.345                         0.344
# 536                          0.260                         0.404
# 3872                         0.235                         0.166
# 10307                        0.350                         0.356
# 11366                        0.395                         0.340
# 14072                        0.311                         0.337
# 2014                         0.268                         0.384
# 14141                        0.216                         0.264
# 11983                        0.313                         0.095
# 10311                        0.303                         0.136
# 9133                         0.394                         0.329
# 16425                        0.456                         0.129
# 2929                         0.696                         0.257
# 12009                        0.412                         0.218
# 13132                        0.351                         0.298
# 14838                        0.335                         0.375
# 16244                        0.621                         0.121
# 293                          0.127                         0.275
# 6992                         0.524                         0.321
#
#        fg_percent_from_x0_3_range  ...  num_of_dunks   fga  \
# 15089                       0.776  ...           236  1665
# 734                         0.717  ...            78  1094
# 14582                       0.792  ...           219  1422
# 15693                       0.568  ...            61  1705
# 9712                        0.580  ...             3  1336
# 11421                       0.549  ...             3  1822
# 14691                       0.577  ...            34  1506
# 536                         0.741  ...            17  1411
# 3872                        0.600  ...            20  1909
# 10307                       0.669  ...            97  1441
# 11366                       0.700  ...            40  1131
# 14072                       0.714  ...           102  1504
# 2014                        0.776  ...            31  1311
# 14141                       0.724  ...            22  1812
# 11983                       0.548  ...             3  1818
# 10311                       0.578  ...             2  1556
# 9133                        0.654  ...            13  1188
# 16425                       0.614  ...             8  1482
# 2929                        0.701  ...           123  1037
# 12009                       0.533  ...            12  1377
# 13132                       0.594  ...            23  1368
# 14838                       0.609  ...            49  1306
# 16244                       0.429  ...            84  1354
# 293                         0.636  ...             3  1648
# 6992                        0.632  ...            35  1015
#
#        offensive_foul_committed  and1  shooting_foul_drawn  fga_blocked  \
# 15089                        45   110                  327           59
# 734                          28    79                  271          121
# 14582                        39   115                  365           50
# 15693                        34    54                  218          121
# 9712                         31    64                  207          121
# 11421                        17    68                  343          103
# 14691                        41    43                  190          141
# 536                          21    59                  181           68
# 3872                         43    76                  358          112
# 10307                        11    62                  210          122
# 11366                        23    69                  275           93
# 14072                        35    70                  304          113
# 2014                         21    72                  188           66
# 14141                        33    53                  211           98
# 11983                        24    56                  294          101
# 10311                        23    68                  326           98
# 9133                         29    48                  168          109
# 16425                        15    38                  130           80
# 2929                         33    79                  278          131
# 12009                        40    43                  172          104
# 13132                        47    46                  184          121
# 14838                        48    50                  209          121
# 16244                        16    40                  158          118
# 293                          13    86                  222           64
# 6992                         19    42                  177          107
#
#        paint_fga  paint_fga_no_dunk  paint_fg%  paint_score
# 15089   1500.165           1264.165   0.347648  2227.255518
# 734     1040.394            962.394   0.283932  1981.933262
# 14582   1252.782           1033.782   0.330264  1947.024424
# 15693   1067.330           1006.330   0.214704  1941.828964
# 9712     904.472            901.472   0.259260  1928.733410
# 11421    774.350            771.350   0.238815  1924.948353
# 14691   1037.634           1003.634   0.244071  1915.713749
# 536      936.904            919.904   0.454974  1909.174409
# 3872     765.509            745.509   0.280200  1802.121450
# 10307   1017.346            920.346   0.305064  1784.673224
# 11366    831.285            791.285   0.334600  1767.669850
# 14072    974.592            872.592   0.321300  1758.160550
# 2014     854.772            823.772   0.470256  1753.746896
# 14141    869.760            847.760   0.278016  1753.303056
# 11983    741.744            738.744   0.237832  1749.634412
# 10311    683.084            681.084   0.252008  1730.279028
# 9133     858.924            845.924   0.299532  1715.915362
# 16425    866.970            858.970   0.237618  1715.529163
# 2929     988.261            865.261   0.293719  1693.234766
# 12009    867.510            855.510   0.200941  1691.845793
# 13132    887.832            864.832   0.270864  1683.904024
# 14838    927.260            878.260   0.272223  1682.657780
# 16244   1004.668            920.668   0.222222  1671.446777
# 293      662.496            659.496   0.330084  1644.273294
# 6992     857.675            822.675   0.232576  1643.245266
#
# [25 rows x 21 columns]

# %%
best_player_szn = sort.drop_duplicates(subset='player', keep='first')

col = ['player', 'pos', 'season', 'tm', 'shooting_foul_drawn', 'offensive_foul_committed', 'and1', 'num_of_dunks', 'paint_fga_no_dunk', 'paint_fg%', 'paint_score']
best_player_szn[col].head(10)
# Out:
#                  player pos  season   tm  shooting_foul_drawn  \
# 15089  Shaquille O'Neal   C    2000  LAL                  327
# 734     Zion Williamson  PF    2024  NOP                  271
# 15693    Antoine Walker  PF    1998  BOS                  218
# 9712      Zach Randolph  PF    2010  MEM                  207
# 11421     Allen Iverson  PG    2006  PHI                  343
# 536        Nikola Jokić   C    2024  DEN                  181
# 3872       James Harden  PG    2019  HOU                  358
# 10307      Al Jefferson   C    2008  MIN                  210
# 11366        Tim Duncan   C    2007  SAS                  275
# 14141    Antawn Jamison  SF    2001  GSW                  211
#
#        offensive_foul_committed  and1  num_of_dunks  paint_fga_no_dunk  \
# 15089                        45   110           236           1264.165
# 734                          28    79            78            962.394
# 15693                        34    54            61           1006.330
# 9712                         31    64             3            901.472
# 11421                        17    68             3            771.350
# 536                          21    59            17            919.904
# 3872                         43    76            20            745.509
# 10307                        11    62            97            920.346
# 11366                        23    69            40            791.285
# 14141                        33    53            22            847.760
#
#        paint_fg%  paint_score
# 15089   0.347648  2227.255518
# 734     0.283932  1981.933262
# 15693   0.214704  1941.828964
# 9712    0.259260  1928.733410
# 11421   0.238815  1924.948353
# 536     0.454974  1909.174409
# 3872    0.280200  1802.121450
# 10307   0.305064  1784.673224
# 11366   0.334600  1767.669850
# 14141   0.278016  1753.303056

# %%
curry = best_player_szn[best_player_szn['player'] == 'Stephen Curry']

print(curry)
# Out:
#       seas_id         player pos   tm  season    mp  avg_dist_fga  \
# 6062    26260  Stephen Curry  PG  GSW    2016  2700          17.4
#
#       percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 6062                        0.225                         0.084
#
#       fg_percent_from_x0_3_range  ...  num_of_dunks   fga  \
# 6062                       0.696  ...             7  1598
#
#       offensive_foul_committed  and1  shooting_foul_drawn  fga_blocked  \
# 6062                         6    32                  130           51
#
#       paint_fga  paint_fga_no_dunk  paint_fg%  paint_score
# 6062    493.782            486.782   0.293712  1075.896492
#
# [1 rows x 21 columns]

# %%
best_player_szn['shots_in_paint_%'] = best_player_szn['paint_fga'] / best_player_szn['fga']
player_pos = pbp[['seas_id', 'pg_percent', 'sg_percent', 'sf_percent', 'pf_percent', 'c_percent']]

combined = best_player_szn.merge(player_pos, on='seas_id')

comb = combined.fillna(0)

threshold = 3.9

df_above_threshold = comb[comb['c_percent'] > threshold]
df_below_threshold = comb[comb['c_percent'] <= threshold]

print("Paint Players:")
print(df_above_threshold[col].head(10))

print("Perimeter Players:")
print(df_below_threshold[col].head(10))
# Out:
# Paint Players:
#               player pos  season   tm  shooting_foul_drawn  \
# 0   Shaquille O'Neal   C    2000  LAL                  327
# 1    Zion Williamson  PF    2024  NOP                  271
# 2     Antoine Walker  PF    1998  BOS                  218
# 3      Zach Randolph  PF    2010  MEM                  207
# 5       Nikola Jokić   C    2024  DEN                  181
# 7       Al Jefferson   C    2008  MIN                  210
# 8         Tim Duncan   C    2007  SAS                  275
# 11       Elton Brand  PF    2000  CHI                  209
# 13       Greg Monroe  PF    2014  DET                  177
# 15       Karl Malone  PF    1997  UTA                  296
#
#     offensive_foul_committed  and1  num_of_dunks  paint_fga_no_dunk  \
# 0                         45   110           236           1264.165
# 1                         28    79            78            962.394
# 2                         34    54            61           1006.330
# 3                         31    64             3            901.472
# 5                         21    59            17            919.904
# 7                         11    62            97            920.346
# 8                         23    69            40            791.285
# 11                        48    50            49            878.260
# 13                        19    42            35            822.675
# 15                        28    87            65            706.361
#
#     paint_fg%  paint_score
# 0    0.347648  2227.255518
# 1    0.283932  1981.933262
# 2    0.214704  1941.828964
# 3    0.259260  1928.733410
# 5    0.454974  1909.174409
# 7    0.305064  1784.673224
# 8    0.334600  1767.669850
# 11   0.272223  1682.657780
# 13   0.232576  1643.245266
# 15   0.303455  1621.693843
# Perimeter Players:
#                      player pos  season   tm  shooting_foul_drawn  \
# 4             Allen Iverson  PG    2006  PHI                  343
# 6              James Harden  PG    2019  HOU                  358
# 9            Antawn Jamison  SF    2001  GSW                  211
# 10              Gary Payton  PG    1997  SEA                  130
# 12            Jalen Brunson  PG    2024  NYK                  222
# 14  Shai Gilgeous-Alexander  PG    2023  OKC                  322
# 16              Luka Dončić  PG    2023  DAL                  308
# 17             LeBron James  SF    2006  CLE                  362
# 23        Russell Westbrook  PG    2018  OKC                  257
# 24             Derrick Rose  PG    2011  CHI                  243
#
#     offensive_foul_committed  and1  num_of_dunks  paint_fga_no_dunk  \
# 4                         17    68             3            771.350
# 6                         43    76            20            745.509
# 9                         33    53            22            847.760
# 10                        15    38             8            858.970
# 12                        13    86             3            659.496
# 14                        30    57            50            721.979
# 16                        12    74            12            608.172
# 17                        35   107           114            697.235
# 23                        16    71            57            697.089
# 24                        14    50            32            699.426
#
#     paint_fg%  paint_score
# 4    0.238815  1924.948353
# 6    0.280200  1802.121450
# 9    0.278016  1753.303056
# 10   0.237618  1715.529163
# 12   0.330084  1644.273294
# 14   0.296964  1623.002624
# 16   0.430610  1606.808135
# 17   0.283179  1604.652376
# 23   0.186966  1564.310131
# 24   0.228514  1556.545299
# /tmp/ipykernel_17/2915721681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_player_szn['shots_in_paint_%'] = best_player_szn['paint_fga'] / best_player_szn['fga']
