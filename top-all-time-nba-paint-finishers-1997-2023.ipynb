# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/top-all-time-nba-paint-finishers-1997-2023?scriptVersionId=197841813" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
sht = pd.read_csv('/kaggle/input/Player Shooting.csv')
tot = pd.read_csv('/kaggle/input/Player Totals.csv')
pbp = pd.read_csv('/kaggle/input/Player Play By Play.csv')

print(sht.head())
print(tot.head())
print(pbp.head())
print(sht.columns)
print(tot.columns)
print(pbp.columns)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/Advanced.csv
# /kaggle/input/Player Season Info.csv
# /kaggle/input/Player Career Info.csv
# /kaggle/input/Player Shooting.csv
# /kaggle/input/Opponent Stats Per Game.csv
# /kaggle/input/Player Totals.csv
# /kaggle/input/Opponent Stats Per 100 Poss.csv
# /kaggle/input/Per 100 Poss.csv
# /kaggle/input/Team Summaries.csv
# /kaggle/input/Player Per Game.csv
# /kaggle/input/All-Star Selections.csv
# /kaggle/input/End of Season Teams (Voting).csv
# /kaggle/input/Player Play By Play.csv
# /kaggle/input/End of Season Teams.csv
# /kaggle/input/Team Stats Per 100 Poss.csv
# /kaggle/input/Per 36 Minutes.csv
# /kaggle/input/Opponent Totals.csv
# /kaggle/input/Team Abbrev.csv
# /kaggle/input/Player Award Shares.csv
# /kaggle/input/Team Totals.csv
# /kaggle/input/Team Stats Per Game.csv
#    seas_id  season  player_id         player  birth_year pos  age  experience  \
# 0    31136    2024       5025     A.J. Green         NaN  SG   24           2
# ...

# %%
df1 = sht[['seas_id', 'player', 'tm', 'season', 'mp', 'avg_dist_fga', 'percent_fga_from_x0_3_range', 'percent_fga_from_x3_10_range', 'fg_percent_from_x0_3_range', 'fg_percent_from_x3_10_range', 'num_of_dunks']]
df2 = tot[['seas_id', 'fga']]
df3 = pbp[['seas_id', 'offensive_foul_committed', 'and1', 'shooting_foul_drawn', 'fga_blocked']]

merge = df1.merge(df2, on='seas_id').merge(df3, on='seas_id')
merge.head()
# Out:
#    seas_id         player   tm  season    mp  avg_dist_fga  \
# 0    31136     A.J. Green  MIL    2024   614          24.1
# 1    31137    A.J. Lawson  DAL    2024   311          13.7
# 2    31138     AJ Griffin  ATL    2024   171          19.5
# 3    31139   Aaron Gordon  DEN    2024  2297           7.4
# 4    31140  Aaron Holiday  HOU    2024  1269          17.3
#
#    percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 0                        0.026                         0.020
# 1                        0.355                         0.190
# 2                        0.048                         0.194
# 3                        0.554                         0.183
# 4                        0.122                         0.170
#
#    fg_percent_from_x0_3_range  fg_percent_from_x3_10_range  num_of_dunks  fga  \
# 0                       1.000                        0.250             0  196
# 1                       0.791                        0.217            12  121
# ...

# %%
merge['paint_fga'] = merge['fga'] * (merge['percent_fga_from_x0_3_range'] + merge['percent_fga_from_x3_10_range'])
merge['paint_fga_no_dunk'] = merge['paint_fga'] - merge['num_of_dunks']
merge['paint_fg%'] = merge['fg_percent_from_x0_3_range'] * merge['fg_percent_from_x3_10_range']

merge.head()
# Out:
#    seas_id         player   tm  season    mp  avg_dist_fga  \
# 0    31136     A.J. Green  MIL    2024   614          24.1
# 1    31137    A.J. Lawson  DAL    2024   311          13.7
# 2    31138     AJ Griffin  ATL    2024   171          19.5
# 3    31139   Aaron Gordon  DEN    2024  2297           7.4
# 4    31140  Aaron Holiday  HOU    2024  1269          17.3
#
#    percent_fga_from_x0_3_range  percent_fga_from_x3_10_range  \
# 0                        0.026                         0.020
# 1                        0.355                         0.190
# 2                        0.048                         0.194
# 3                        0.554                         0.183
# 4                        0.122                         0.170
#
#    fg_percent_from_x0_3_range  fg_percent_from_x3_10_range  num_of_dunks  fga  \
# 0                       1.000                        0.250             0  196
# 1                       0.791                        0.217            12  121
# ...

# %%
merge['paint_score'] = (merge['paint_fga_no_dunk'] * 1.5) + (merge['paint_fg%'] * 3) + (merge['and1'] * 3) + (merge['offensive_foul_committed'] * -3) + (merge['shooting_foul_drawn'] * 1.25) + (merge['num_of_dunks'] * -2)

sort = merge.sort_values(by='paint_score', ascending=False)

sort.head(25)
# Out:
#        seas_id            player   tm  season    mp  avg_dist_fga  \
# 15089    17142  Shaquille O'Neal  LAL    2000  3163           5.8
# 14582    17668  Shaquille O'Neal  LAL    2001  2924           4.7
# 734      31870   Zion Williamson  NOP    2024  2207           4.0
# 11421    19913     Allen Iverson  PHI    2006  3103          11.4
# 15693    15689    Antoine Walker  BOS    1998  3268          10.3
# 9712     22731     Zach Randolph  MEM    2010  3051           7.5
# 536      31672      Nikola Jokić  DEN    2024  2737           9.7
# 14691    16744    Antoine Walker  BOS    2000  3003           9.6
# 3872     27871      James Harden  HOU    2019  2867          16.4
# 10307    20989      Al Jefferson  MIN    2008  2919           6.9
# 14072    18196        Tim Duncan  SAS    2002  3329           7.6
# 11366    20940        Tim Duncan  SAS    2007  2726           6.6
# 11983    19327     Allen Iverson  PHI    2005  3174          12.2
# ...

# %%
best_player_szn = sort.drop_duplicates(subset='player', keep='first')

col = ['player', 'season', 'tm', 'shooting_foul_drawn', 'offensive_foul_committed', 'and1', 'num_of_dunks', 'paint_fga_no_dunk', 'paint_fg%', 'paint_score']
best_player_szn[col].head(10)
# Out:
#                  player  season   tm  shooting_foul_drawn  \
# 15089  Shaquille O'Neal    2000  LAL                  327
# 734     Zion Williamson    2024  NOP                  271
# 11421     Allen Iverson    2006  PHI                  343
# 15693    Antoine Walker    1998  BOS                  218
# 9712      Zach Randolph    2010  MEM                  207
# 536        Nikola Jokić    2024  DEN                  181
# 3872       James Harden    2019  HOU                  358
# 10307      Al Jefferson    2008  MIN                  210
# 14072        Tim Duncan    2002  SAS                  304
# 14141    Antawn Jamison    2001  GSW                  211
#
#        offensive_foul_committed  and1  num_of_dunks  paint_fga_no_dunk  \
# 15089                        45   110           236           1264.165
# 734                          28    79            78            962.394
# 11421                        17    68             3            771.350
# ...
