# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/2023-24-nba-paint-finishers?scriptVersionId=197369921" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
pbp = pd.read_csv('/kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Play by Play.csv')
sht = pd.read_csv('/kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Shooting and Dist.csv')
ttl = pd.read_csv('/kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Totals.csv')

print(pbp.head())
print(sht.head())
print(ttl.head())

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Play by Play.csv
# /kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Shooting and Dist.csv
# /kaggle/input/nba-2023-24-statss/Untitled spreadsheet - Totals.csv
#    Rk                   Player Pos  Age   Tm   G    MP   PG%  SG%  SF%  PF%  \
# 0   1    Giannis Antetokounmpo  PF   29  MIL  73  2567   NaN  NaN  NaN  59%
# 1   2            Jalen Brunson  PG   27  NYK  77  2726  100%  NaN  NaN  NaN
# 2   3          Zion Williamson  PF   23  NOP  70  2207   NaN  NaN   1%  86%
# 3   4              Luka Dončić  PG   24  DAL  70  2624   74%  26%  NaN  NaN
# 4   5  Shai Gilgeous-Alexander  PG   25  OKC  75  2553   99%   1%  NaN  NaN
#
#     C%  BadPass  LostBall  Shoot Fouls Cmt  Off. Fouls Cmt  Shoot Foul Drawn  \
# 0  41%       75        72               83              45               377
# 1  NaN       96        67               74              13               222
# 2  14%       78        75               90              28               271
# 3  NaN      200        61               77               7               283
# 4  NaN       67        57               99              14               272
#
#    Off. Fouls Drawn  And1\n▼  Blkd
# 0                 7      105    90
# 1                75       86    64
# 2                 3       79   121
# 3                12       78    50
# 4                11       74    77
#    Rk            Player Pos  Age   Tm   G    MP    FG%  Dist.  Unnamed: 9  \
# 0   1     Caleb Houstan  SF   21  ORL  59   815  0.388   23.9         NaN
# 1   2       Sam Merrill  SG   27  CLE  61  1069  0.402   23.6         NaN
# 2   3        Sam Hauser  SF   26  BOS  79  1741  0.446   22.7         NaN
# 3   4  Garrison Mathews  SG   27  ATL  66   992  0.456   22.6         NaN
# 4   5    Doug McDermott  SF   32  TOT  64   904  0.433   21.9         NaN
#
#    ...  FG% for 3P  Unnamed: 23  %FGA Dunks  # Dunks  Unnamed: 26  \
# 0  ...       0.373          NaN       0.000        0          NaN
# 1  ...       0.404          NaN       0.000        0          NaN
# 2  ...       0.424          NaN       0.016        9          NaN
# 3  ...       0.440          NaN       0.000        0          NaN
# 4  ...       0.410          NaN       0.021        6          NaN
#
#    %3PA Corner  3P% Corner  Unnamed: 29  Att Heaves  # Heaves
# 0        0.378       0.397          NaN           0         0
# 1        0.195       0.449          NaN           1         0
# 2        0.241       0.518          NaN           2         0
# 3        0.316       0.459          NaN           0         0
# 4        0.214       0.408          NaN           0         0
#
# [5 rows x 32 columns]
#    Rk                   Player  Age Team Pos   G  GS    MP   FG  FGA\n▼  ...  \
# 0   1              Luka Dončić   24  DAL  PG  70  70  2624  804    1652  ...
# 1   2            Jalen Brunson   27  NYK  PG  77  77  2726  790    1648  ...
# 2   3          Anthony Edwards   22  MIN  SG  79  78  2770  718    1558  ...
# 3   4             De'Aaron Fox   26  SAC  PG  74  74  2659  720    1549  ...
# 4   5  Shai Gilgeous-Alexander   25  OKC  PG  75  75  2553  796    1487  ...
#
#      FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.786   59  588  647  686   99   38  282  149  2370
# 1  0.847   43  235  278  519   70   13  186  144  2212
# 2  0.836   52  378  430  405  101   42  241  141  2049
# 3  0.738   67  273  340  418  150   31  194  193  1966
# 4  0.874   65  350  415  465  150   67  162  184  2254
#
# [5 rows x 30 columns]

# %%
pbp.rename(columns={'And1\n▼': 'And1'}, inplace=True)
ttl.rename(columns={'FGA\n▼': 'FGA'}, inplace=True)

print(pbp.columns)
print(sht.columns)
print(ttl.columns)
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PG%', 'SG%', 'SF%',
#        'PF%', 'C%', 'BadPass', 'LostBall', 'Shoot Fouls Cmt', 'Off. Fouls Cmt',
#        'Shoot Foul Drawn', 'Off. Fouls Drawn', 'And1', 'Blkd'],
#       dtype='object')
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'FG%', 'Dist.',
#        'Unnamed: 9', '%FGA 2P', '%FGA 0-3', '%FGA 3-10', '%FGA 10-16',
#        '%FGA 16-3P', '%FGA 3P', 'Unnamed: 16', 'FG% for 2P', 'FG% for 0-3',
#        'FG% for 3-10', 'FG% for 10-16', 'FG% for 16-3P', 'FG% for 3P',
#        'Unnamed: 23', '%FGA Dunks', '# Dunks', 'Unnamed: 26', '%3PA Corner',
#        '3P% Corner', 'Unnamed: 29', 'Att Heaves', '# Heaves'],
#       dtype='object')
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1 = pbp[['Player', 'Pos', 'G', 'MP', 'Off. Fouls Cmt', 'And1', 'Blkd']]
df2 = sht[['Player', 'Dist.', '%FGA 0-3', '%FGA 3-10', 'FG% for 0-3', 'FG% for 3-10', '# Dunks']]
df3 = ttl[['Player', 'FGA', 'PTS']]

# Merging the selected columns
merge = df1.merge(df2, on='Player').merge(df3, on='Player')
print(merge.head())
print(merge.columns)
# Out:
#                     Player Pos   G    MP  Off. Fouls Cmt  And1  Blkd  Dist.  \
# 0    Giannis Antetokounmpo  PF  73  2567              45   105    90    6.7
# 1            Jalen Brunson  PG  77  2726              13    86    64   14.3
# 2          Zion Williamson  PF  70  2207              28    79   121    4.0
# 3              Luka Dončić  PG  70  2624               7    78    50   16.9
# 4  Shai Gilgeous-Alexander  PG  75  2553              14    74    77   11.3
#
#    %FGA 0-3  %FGA 3-10  FG% for 0-3  FG% for 3-10  # Dunks   FGA   PTS
# 0     0.519      0.251        0.818         0.452      251  1369  2222
# 1     0.127      0.275        0.636         0.519        3  1648  2212
# 2     0.547      0.404        0.717         0.396       78  1094  1601
# 3     0.123      0.192        0.838         0.569        2  1652  2370
# 4     0.252      0.224        0.731         0.492       37  1487  2254
# Index(['Player', 'Pos', 'G', 'MP', 'Off. Fouls Cmt', 'And1', 'Blkd', 'Dist.',
#        '%FGA 0-3', '%FGA 3-10', 'FG% for 0-3', 'FG% for 3-10', '# Dunks',
#        'FGA', 'PTS'],
#       dtype='object')

# %%
merge['Paint Att'] = merge['FGA'] * (merge['%FGA 0-3'] + merge['%FGA 3-10'])
merge['Paint Att No Dnk'] = merge['Paint Att'] - merge['# Dunks']
merge['Paint %'] = merge['FG% for 0-3'] * merge['FG% for 3-10']

merge.head()
# Out:
#                     Player Pos   G    MP  Off. Fouls Cmt  And1  Blkd  Dist.  \
# 0    Giannis Antetokounmpo  PF  73  2567              45   105    90    6.7
# 1            Jalen Brunson  PG  77  2726              13    86    64   14.3
# 2          Zion Williamson  PF  70  2207              28    79   121    4.0
# 3              Luka Dončić  PG  70  2624               7    78    50   16.9
# 4  Shai Gilgeous-Alexander  PG  75  2553              14    74    77   11.3
#
#    %FGA 0-3  %FGA 3-10  FG% for 0-3  FG% for 3-10  # Dunks   FGA   PTS  \
# 0     0.519      0.251        0.818         0.452      251  1369  2222
# 1     0.127      0.275        0.636         0.519        3  1648  2212
# 2     0.547      0.404        0.717         0.396       78  1094  1601
# 3     0.123      0.192        0.838         0.569        2  1652  2370
# 4     0.252      0.224        0.731         0.492       37  1487  2254
#
#    Paint Att  Paint Att No Dnk   Paint %
# 0   1054.130           803.130  0.369736
# 1    662.496           659.496  0.330084
# 2   1040.394           962.394  0.283932
# 3    520.380           518.380  0.476822
# 4    707.812           670.812  0.359652

# %%
print(merge.dtypes)
print(merge['Pos'].unique())
print(merge['Pos'].value_counts())
# Out:
# Player               object
# Pos                  object
# G                     int64
# MP                    int64
# Off. Fouls Cmt        int64
# And1                  int64
# Blkd                  int64
# Dist.               float64
# %FGA 0-3            float64
# %FGA 3-10           float64
# FG% for 0-3         float64
# FG% for 3-10        float64
# # Dunks               int64
# FGA                   int64
# PTS                   int64
# Paint Att           float64
# Paint Att No Dnk    float64
# Paint %             float64
# dtype: object
# ['PF' 'PG' 'SF' 'SG' 'C' 'PG-SG' 'C-PF' 'PF-C' 'SF-SG']
# Pos
# SF       54
# SG       50
# PG       45
# C        45
# PF       41
# PG-SG     3
# C-PF      1
# PF-C      1
# SF-SG     1
# Name: count, dtype: int64

# %%
# Create a new DataFrame with only Guards
guards = merge[merge['Pos'].isin(['PG', 'SG', 'PG-SG'])]

# Display the new table
guards.head()
# Out:
#                      Player Pos   G    MP  Off. Fouls Cmt  And1  Blkd  Dist.  \
# 1             Jalen Brunson  PG  77  2726              13    86    64   14.3
# 3               Luka Dončić  PG  70  2624               7    78    50   16.9
# 4   Shai Gilgeous-Alexander  PG  75  2553              14    74    77   11.3
# 7           Anthony Edwards  SG  79  2770              15    69    56   14.1
# 12             Tyrese Maxey  PG  70  2626               9    54    90   14.7
#
#     %FGA 0-3  %FGA 3-10  FG% for 0-3  FG% for 3-10  # Dunks   FGA   PTS  \
# 1      0.127      0.275        0.636         0.519        3  1648  2212
# 3      0.123      0.192        0.838         0.569        2  1652  2370
# 4      0.252      0.224        0.731         0.492       37  1487  2254
# 7      0.228      0.192        0.707         0.438       67  1558  2049
# 12     0.222      0.229        0.667         0.406        6  1419  1816
#
#     Paint Att  Paint Att No Dnk   Paint %
# 1     662.496           659.496  0.330084
# 3     520.380           518.380  0.476822
# 4     707.812           670.812  0.359652
# 7     654.360           587.360  0.309666
# 12    639.969           633.969  0.270802

# %%
guards['Paint Score'] = ((guards['And1'] * 1.75) +
                        (guards['Off. Fouls Cmt'] * 0.5) + 
                        (guards['Paint Att No Dnk'] * 1.2) +
                        (guards['Paint %'] * 2) -
                        (guards['# Dunks'] / guards['FGA']))


# Sort by Paint Score in descending order
guards_sorted = guards.sort_values(by='Paint Score', ascending=False)

# Display the sorted DataFrame
guards_sorted.head(10)
# Out:
# /tmp/ipykernel_17/2684444911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   guards['Paint Score'] = ((guards['And1'] * 1.75) +
#                      Player Pos   G    MP  Off. Fouls Cmt  And1  Blkd  Dist.  \
# 1             Jalen Brunson  PG  77  2726              13    86    64   14.3
# 4   Shai Gilgeous-Alexander  PG  75  2553              14    74    77   11.3
# 12             Tyrese Maxey  PG  70  2626               9    54    90   14.7
# 7           Anthony Edwards  SG  79  2770              15    69    56   14.1
# 22             De'Aaron Fox  PG  74  2659              10    44    68   15.0
# 3               Luka Dončić  PG  70  2624               7    78    50   16.9
# 27            Collin Sexton  SG  78  2075              16    42   113   12.3
# 47               RJ Barrett  SG  58  1838              14    30    90   10.2
# 52          Dejounte Murray  SG  78  2783              14    29    69   14.9
# 77              Josh Giddey  SG  80  2011              12    21    70   10.9
#
#     %FGA 0-3  %FGA 3-10  FG% for 0-3  FG% for 3-10  # Dunks   FGA   PTS  \
# 1      0.127      0.275        0.636         0.519        3  1648  2212
# 4      0.252      0.224        0.731         0.492       37  1487  2254
# 12     0.222      0.229        0.667         0.406        6  1419  1816
# 7      0.228      0.192        0.707         0.438       67  1558  2049
# 22     0.134      0.248        0.720         0.534       24  1549  1966
# 3      0.123      0.192        0.838         0.569        2  1652  2370
# 27     0.203      0.346        0.744         0.451       23  1038  1458
# 47     0.364      0.276        0.694         0.420       39   880  1170
# 52     0.170      0.191        0.581         0.464       14  1463  1753
# 77     0.283      0.336        0.671         0.425        4   847   986
#
#     Paint Att  Paint Att No Dnk   Paint %  Paint Score
# 1     662.496           659.496  0.330084   949.053548
# 4     707.812           670.812  0.359652   942.168822
# 12    639.969           633.969  0.270802   860.300176
# 7     654.360           587.360  0.309666   833.658328
# 22    591.718           567.718  0.384480   764.015066
# 3     520.380           518.380  0.476822   763.008433
# 27    569.862           546.862  0.335544   738.383330
# 47    563.200           524.200  0.291480   689.078642
# 52    528.143           514.143  0.269584   675.251199
# 77    524.293           520.293  0.285175   667.667227
