# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/historic-9cat-fantasy-basketball-teams?scriptVersionId=198556140" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
tm = pd.read_csv('/kaggle/input/nba-aba-baa-stats/Team Totals.csv')

print(tm.head())
print(tm.columns)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nba-aba-baa-stats/Advanced.csv
# /kaggle/input/nba-aba-baa-stats/Player Season Info.csv
# /kaggle/input/nba-aba-baa-stats/Player Career Info.csv
# /kaggle/input/nba-aba-baa-stats/Player Shooting.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Stats Per Game.csv
# /kaggle/input/nba-aba-baa-stats/Player Totals.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Stats Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Team Summaries.csv
# /kaggle/input/nba-aba-baa-stats/Player Per Game.csv
# /kaggle/input/nba-aba-baa-stats/All-Star Selections.csv
# /kaggle/input/nba-aba-baa-stats/End of Season Teams (Voting).csv
# /kaggle/input/nba-aba-baa-stats/Player Play By Play.csv
# /kaggle/input/nba-aba-baa-stats/End of Season Teams.csv
# /kaggle/input/nba-aba-baa-stats/Team Stats Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Per 36 Minutes.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Totals.csv
# ...

# %%
cat9 = tm[['season', 'g', 'team', 'abbreviation', 'pts', 'trb', 'ast', 'x3p', 'blk', 'stl', 'fg_percent', 'ft_percent', 'tov']]

c9_clean = cat9.dropna()
c9_cleaned = c9_clean.copy()
c9_cleaned.head()
# Out:
#    season     g               team abbreviation     pts     trb     ast  \
# 0    2024  82.0      Atlanta Hawks          ATL  9703.0  3663.0  2180.0
# 1    2024  82.0     Boston Celtics          BOS  9887.0  3799.0  2207.0
# 2    2024  82.0      Brooklyn Nets          BRK  9050.0  3613.0  2102.0
# 3    2024  82.0      Chicago Bulls          CHI  9206.0  3593.0  2048.0
# 4    2024  82.0  Charlotte Hornets          CHO  8740.0  3303.0  2033.0
#
#       x3p    blk    stl  fg_percent  ft_percent     tov
# 0  1125.0  369.0  615.0       0.465       0.797  1110.0
# 1  1351.0  538.0  557.0       0.487       0.807   979.0
# 2  1089.0  424.0  556.0       0.456       0.756  1076.0
# 3   941.0  394.0  638.0       0.470       0.791  1004.0
# 4   989.0  371.0  562.0       0.460       0.786  1129.0

# %%
c9_cleaned['cat9_finish'] = c9_cleaned['pts'] + c9_cleaned['trb'] + c9_cleaned['ast'] + c9_cleaned['x3p'] + c9_cleaned['blk'] + c9_cleaned['stl'] + c9_cleaned['fg_percent'] + c9_cleaned['ft_percent'] - c9_cleaned['tov']
c9_cleaned['per_game_avg'] = c9_cleaned['cat9_finish'] / c9_cleaned['g']

sort = c9_cleaned.sort_values(by=['per_game_avg'], ascending=False)

# Display the result
sort.head()
# Out:
#      season     g             team abbreviation      pts     trb     ast  \
# 1      2024  82.0   Boston Celtics          BOS   9887.0  3799.0  2207.0
# 11     2024  82.0   Indiana Pacers          IND  10110.0  3405.0  2522.0
# 140    2020  73.0  Milwaukee Bucks          MIL   8663.0  3774.0  1889.0
# 109    2021  72.0  Milwaukee Bucks          MIL   8649.0  3465.0  1834.0
# 171    2019  82.0  Milwaukee Bucks          MIL   9686.0  4078.0  2136.0
#
#         x3p    blk    stl  fg_percent  ft_percent     tov  cat9_finish  \
# 1    1351.0  538.0  557.0       0.487       0.807   979.0    17361.294
# 11   1082.0  481.0  631.0       0.507       0.782  1059.0    17173.289
# 140  1007.0  429.0  526.0       0.476       0.742  1102.0    15187.218
# 109  1038.0  334.0  585.0       0.487       0.760   995.0    14911.247
# 171  1105.0  486.0  615.0       0.476       0.773  1137.0    16970.249
#
#      per_game_avg
# 1      211.723098
# 11     209.430354
# 140    208.044082
# 109    207.100653
# ...

# %%
best_szn = sort.drop_duplicates(subset='team', keep='first')
best_szn.head(10)
# Out:
#      season     g                   team abbreviation      pts     trb  \
# 1      2024  82.0         Boston Celtics          BOS   9887.0  3799.0
# 11     2024  82.0         Indiana Pacers          IND  10110.0  3405.0
# 140    2020  73.0        Milwaukee Bucks          MIL   8663.0  3774.0
# 164    2019  82.0  Golden State Warriors          GSW   9650.0  3787.0
# 76     2022  82.0      Memphis Grizzlies          MEM   9480.0  4032.0
# 20     2024  82.0  Oklahoma City Thunder          OKC   9847.0  3447.0
# 121    2021  72.0              Utah Jazz          UTA   8382.0  3474.0
# 95     2021  72.0          Brooklyn Nets          BRK   8537.0  3199.0
# 66     2022  82.0      Charlotte Hornets          CHO   9457.0  3655.0
# 130    2020  75.0       Dallas Mavericks          DAL   8776.0  3520.0
#
#         ast     x3p    blk    stl  fg_percent  ft_percent     tov  \
# 1    2207.0  1351.0  538.0  557.0       0.487       0.807   979.0
# ...

# %%
leaders = sort.groupby('season').first().reset_index()
leaders.head(77)
# Out:
#     season     g                     team abbreviation      pts     trb  \
# 0     1974  84.0  San Diego Conquistadors          SDA   9506.0  4170.0
# 1     1975  84.0           Denver Nuggets          DNA   9969.0  3816.0
# 2     1976  84.0           Denver Nuggets          DNA  10237.0  4087.0
# 3     1980  82.0        San Antonio Spurs          SAS   9788.0  3668.0
# 4     1981  82.0           Denver Nuggets          DEN   9986.0  3822.0
# 5     1982  82.0           Denver Nuggets          DEN  10371.0  3592.0
# 6     1983  82.0           Denver Nuggets          DEN  10105.0  3738.0
# 7     1984  82.0           Denver Nuggets          DEN  10147.0  3577.0
# 8     1985  82.0           Denver Nuggets          DEN   9841.0  3634.0
# 9     1986  82.0       Los Angeles Lakers          LAL   9618.0  3656.0
# 10    1987  82.0       Los Angeles Lakers          LAL   9656.0  3642.0
# 11    1988  82.0           Denver Nuggets          DEN   9573.0  3605.0
# ...
