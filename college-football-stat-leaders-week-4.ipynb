# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/college-football-stat-leaders-week-5?scriptVersionId=199496095" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

qb = pd.read_csv('/kaggle/input/week5cfb/cfb stats week 5 - pass.csv')
wr = pd.read_csv('/kaggle/input/week5cfb/cfb stats week 5 - receive.csv')
rb = pd.read_csv('/kaggle/input/week5cfb/cfb stats week 5 - rush.csv')
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cfb-stats/cfb stats week 4 - rush.csv
# /kaggle/input/cfb-stats/cfb stats week 4 - receive.csv
# /kaggle/input/cfb-stats/cfb stats week 4 - pass.csv
# /kaggle/input/week5cfb/cfb stats week 5 - pass.csv
# /kaggle/input/week5cfb/cfb stats week 5 - receive.csv
# /kaggle/input/week5cfb/cfb stats week 5 - rush.csv

# %%
print(qb.head())
print(qb.columns)
print(rb.head())
print(rb.columns)
print(wr.head())
print(wr.columns)
# Out:
#     Rk             Player             Team      Conf  G  Cmp  Att  Cmp%   Yds  \
# 0  1.0        Jaxson Dart         Ole Miss       SEC  5  113  146  77.4  1815
# 1  2.0       Cameron Ward       Miami (FL)       ACC  5  113  161  70.2  1782
# 2  3.0        Josh Hoover  Texas Christian    Big 12  5  139  199  69.8  1774
# 3  4.0  Garrett Nussmeier              LSU       SEC  5  138  198  69.7  1652
# 4  5.0    Chandler Morris      North Texas  American  5  123  188  65.4  1643
#
#    TD   TD%  Int  Int%   Y/A   AY/A   Y/C    Y/G   Rate  Awards
# 0  13   8.9    2   1.4  12.4  13.60  16.1  363.0  208.5     NaN
# 1  18  11.2    4   2.5  11.1  12.19  15.8  356.4  195.1     NaN
# 2  14   7.0    4   2.0   8.9   9.42  12.8  354.8  163.9     NaN
# 3  15   7.6    4   2.0   8.3   8.95  12.0  330.4  160.7     NaN
# 4  16   8.5    6   3.2   8.7   9.01  13.4  328.6  160.5     NaN
# Index(['Rk', 'Player', 'Team', 'Conf', 'G', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD',
# ...

# %%
qb['Score'] = (qb['Cmp%'] * 2.5) + (qb['Y/G'] * 1.5) + (qb['TD'] * 3) + (qb['Int'] * -3) + (qb['Y/A'] * 2)
rb['Score'] = (rb['RAvg'] * 1.5) + (rb['RTD'] * 3) + ((rb['RYds'] / rb['G']) * 1.5)
wr['Score'] = (wr['Rec'] * 1.5) + (wr['RecAvg'] * 2) + (wr['RecTD'] * 3) + ((wr['RecYds'] / wr['G']) * 2)

rb['Y/G'] = rb['RYds'] / rb['G']
wr['Y/G'] = wr['RecYds'] / wr['G']

qb_sort = qb.sort_values(by='Score', ascending=False)
rb_sort = rb.sort_values(by='Score', ascending=False)
wr_sort = wr.sort_values(by='Score', ascending=False)

print(qb_sort.head())
print(rb_sort.head())
print(wr_sort.head())
# Out:
#     Rk             Player             Team    Conf  G  Cmp  Att  Cmp%   Yds  \
# 0  1.0        Jaxson Dart         Ole Miss     SEC  5  113  146  77.4  1815
# 1  2.0       Cameron Ward       Miami (FL)     ACC  5  113  161  70.2  1782
# 2  3.0        Josh Hoover  Texas Christian  Big 12  5  139  199  69.8  1774
# 8  9.0        Kyle McCord         Syracuse     ACC  4  114  177  64.4  1459
# 3  4.0  Garrett Nussmeier              LSU     SEC  5  138  198  69.7  1652
#
#    TD   TD%  Int  Int%   Y/A   AY/A   Y/C    Y/G   Rate  Awards   Score
# 0  13   8.9    2   1.4  12.4  13.60  16.1  363.0  208.5     NaN  795.80
# 1  18  11.2    4   2.5  11.1  12.19  15.8  356.4  195.1     NaN  774.30
# 2  14   7.0    4   2.0   8.9   9.42  12.8  354.8  163.9     NaN  754.50
# 8  14   7.9    5   2.8   8.2   8.55  12.8  364.8  154.1     NaN  751.60
# 3  15   7.6    4   2.0   8.3   8.95  12.0  330.4  160.7     NaN  719.45
#     Rk           Player          School     Conf  G  RAtt  RYds  RAvg  RTD  \
# ...
