# %% [markdown]
# <a href="https://www.kaggle.com/code/vtrackstar/top-individual-9cat-player-seasons-nba?scriptVersionId=198926068" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nba-aba-baa-stats/Advanced.csv
# /kaggle/input/nba-aba-baa-stats/Player Season Info.csv
# /kaggle/input/nba-aba-baa-stats/Player Career Info.csv
# /kaggle/input/nba-aba-baa-stats/Player Shooting.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Stats Per Game.csv
# /kaggle/input/nba-aba-baa-stats/Player Totals.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Stats Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Team Summaries.csv
# /kaggle/input/nba-aba-baa-stats/Player Per Game.csv
# /kaggle/input/nba-aba-baa-stats/All-Star Selections.csv
# /kaggle/input/nba-aba-baa-stats/End of Season Teams (Voting).csv
# /kaggle/input/nba-aba-baa-stats/Player Play By Play.csv
# /kaggle/input/nba-aba-baa-stats/End of Season Teams.csv
# /kaggle/input/nba-aba-baa-stats/Team Stats Per 100 Poss.csv
# /kaggle/input/nba-aba-baa-stats/Per 36 Minutes.csv
# /kaggle/input/nba-aba-baa-stats/Opponent Totals.csv
# ...

# %%
ttl = pd.read_csv('/kaggle/input/nba-aba-baa-stats/Player Totals.csv')
print(ttl.head())
print(ttl.columns)
# Out:
#    seas_id  season  player_id         player  birth_year pos   age  \
# 0    31136    2024       5025     A.J. Green         NaN  SG  24.0
# 1    31137    2024       5026    A.J. Lawson         NaN  SG  23.0
# 2    31138    2024       5027     AJ Griffin         NaN  SF  20.0
# 3    31139    2024       4219   Aaron Gordon         NaN  PF  28.0
# 4    31140    2024       4582  Aaron Holiday         NaN  PG  27.0
#
#    experience   lg   tm  ...  ft_percent    orb    drb    trb  ast   stl  \
# 0           2  NBA  MIL  ...       0.895    9.0   55.0   64.0   30   9.0
# 1           2  NBA  DAL  ...       0.652   14.0   36.0   50.0   20  10.0
# 2           2  NBA  ATL  ...       1.000    2.0   16.0   18.0    5   1.0
# 3          10  NBA  DEN  ...       0.658  174.0  297.0  471.0  259  56.0
# 4           6  NBA  HOU  ...       0.921   23.0  100.0  123.0  140  42.0
#
#     blk    tov   pf   pts
# 0   4.0   12.0   49   252
# 1   3.0   14.0   22   136
# 2   2.0    8.0    6    48
# ...

# %%
cat9 = ttl[['seas_id', 'season', 'player', 'pos', 'tm', 'g', 'pts', 'trb', 'ast', 'stl', 'blk', 'x3p', 'fg_percent', 'ft_percent', 'tov']]
cat9.head()
# Out:
#    seas_id  season         player pos   tm   g   pts    trb  ast   stl   blk  \
# 0    31136    2024     A.J. Green  SG  MIL  56   252   64.0   30   9.0   4.0
# 1    31137    2024    A.J. Lawson  SG  DAL  42   136   50.0   20  10.0   3.0
# 2    31138    2024     AJ Griffin  SF  ATL  20    48   18.0    5   1.0   2.0
# 3    31139    2024   Aaron Gordon  PF  DEN  73  1013  471.0  259  56.0  45.0
# 4    31140    2024  Aaron Holiday  PG  HOU  78   514  123.0  140  42.0   6.0
#
#     x3p  fg_percent  ft_percent    tov
# 0  69.0       0.423       0.895   12.0
# 1  13.0       0.446       0.652   14.0
# 2  10.0       0.290       1.000    8.0
# 3  40.0       0.556       0.658  105.0
# 4  84.0       0.446       0.921   53.0

# %%
cat9['score'] = cat9['pts'] + cat9['trb'] + cat9['ast'] + cat9['stl'] + cat9['blk'] + cat9['x3p'] + cat9['fg_percent'] + cat9['ft_percent'] - cat9['tov']
sort = cat9.sort_values(by='score', ascending=False)
sort.head(20)
# Out:
# /tmp/ipykernel_17/1554253853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat9['score'] = cat9['pts'] + cat9['trb'] + cat9['ast'] + cat9['stl'] + cat9['blk'] + cat9['x3p'] + cat9['fg_percent'] + cat9['ft_percent'] - cat9['tov']
#        seas_id  season             player pos   tm   g   pts     trb  ast  \
# 5443     26815    2017  Russell Westbrook  PG  OKC  81  2558   864.0  840
# 3872     27871    2019       James Harden  PG  HOU  78  2818   518.0  586
# 20354    11647    1989     Michael Jordan  SG  CHI  81  2633   652.0  650
# 19889    12079    1990     Michael Jordan  SG  CHI  82  2753   565.0  519
# 21188    10813    1987     Michael Jordan  SG  CHI  82  3041   430.0  377
# ...

# %%
best_szn = sort.drop_duplicates(subset='player', keep='first')
best_szn.head(10)
# Out:
#        seas_id  season             player pos   tm   g   pts     trb  ast  \
# 5443     26815    2017  Russell Westbrook  PG  OKC  81  2558   864.0  840
# 3872     27871    2019       James Harden  PG  HOU  78  2818   518.0  586
# 20354    11647    1989     Michael Jordan  SG  CHI  81  2633   652.0  650
# 25197     6727    1976      Julius Erving  SF  NYA  84  2462   925.0  423
# 25541     6220    1975    George McGinnis  PF  INA  79  2353  1126.0  495
# 457      31593    2024        Luka Dončić  PG  DAL  70  2370   647.0  686
# 536      31672    2024       Nikola Jokić   C  DEN  79  2085   976.0  708
# 17891    13717    1994     David Robinson   C  SAS  80  2383   855.0  381
# 15089    17142    2000   Shaquille O'Neal   C  LAL  79  2344  1078.0  299
# 23054     8978    1982       Moses Malone   C  HOU  81  2520  1188.0  142
#
#          stl    blk    x3p  fg_percent  ft_percent    tov     score
# 5443   132.0   31.0  200.0       0.425       0.845  438.0  4188.270
# ...

# %%
guard = sort[sort['pos'].isin(['PG', 'SG'])]
forward = sort[sort['pos'].isin(['SF', 'PF'])]
center = sort[sort['pos'].isin(['C'])]

# %%
guard.head(10)
# Out:
#        seas_id  season             player pos   tm   g   pts    trb  ast  \
# 5443     26815    2017  Russell Westbrook  PG  OKC  81  2558  864.0  840
# 3872     27871    2019       James Harden  PG  HOU  78  2818  518.0  586
# 20354    11647    1989     Michael Jordan  SG  CHI  81  2633  652.0  650
# 19889    12079    1990     Michael Jordan  SG  CHI  82  2753  565.0  519
# 21188    10813    1987     Michael Jordan  SG  CHI  82  3041  430.0  377
# 20779    11208    1988     Michael Jordan  SG  CHI  82  2868  449.0  485
# 5191     26560    2017       James Harden  PG  HOU  81  2356  659.0  907
# 457      31593    2024        Luka Dončić  PG  DAL  70  2370  647.0  686
# 11708    20200    2006        Kobe Bryant  SG  LAL  80  2832  425.0  360
# 19453    12543    1991     Michael Jordan  SG  CHI  82  2580  492.0  453
#
#          stl    blk    x3p  fg_percent  ft_percent    tov     score
# 5443   132.0   31.0  200.0       0.425       0.845  438.0  4188.270
# ...

# %%
forward.head(10)
# Out:
#        seas_id  season           player pos   tm   g   pts     trb  ast  \
# 25197     6727    1976    Julius Erving  SF  NYA  84  2462   925.0  423
# 25541     6220    1975  George McGinnis  PF  INA  79  2353  1126.0  495
# 25622     6301    1975    Julius Erving  SF  NYA  84  2343   914.0  462
# 7122     24828    2014     Kevin Durant  SF  OKC  81  2593   598.0  445
# 21889    10015    1985       Larry Bird  SF  BOS  80  2295   842.0  531
# 26037     5879    1974    Julius Erving  SF  NYA  84  2299   899.0  434
# 4692     27322    2018     LeBron James  PF  CLE  82  2251   709.0  747
# 12862    19036    2004    Kevin Garnett  PF  MIN  82  1987  1139.0  409
# 10049    21909    2009     LeBron James  SF  CLE  81  2304   613.0  587
# 11718    20211    2006     LeBron James  SF  CLE  79  2478   556.0  521
#
#          stl    blk    x3p  fg_percent  ft_percent    tov     score
# 25197  207.0  160.0   34.0       0.507       0.801  307.0  3905.308
# ...

# %%
center.head(10)
# Out:
#        seas_id  season            player pos   tm   g   pts     trb  ast  \
# 536      31672    2024      Nikola Jokić   C  DEN  79  2085   976.0  708
# 17891    13717    1994    David Robinson   C  SAS  80  2383   855.0  381
# 15089    17142    2000  Shaquille O'Neal   C  LAL  79  2344  1078.0  299
# 23054     8978    1982      Moses Malone   C  HOU  81  2520  1188.0  142
# 18430    13326    1993   Hakeem Olajuwon   C  HOU  82  2140  1068.0  291
# 18189    14015    1994  Shaquille O'Neal   C  ORL  81  2377  1072.0  195
# 19755    11945    1990   Hakeem Olajuwon   C  HOU  82  1995  1149.0  234
# 2014     30247    2022      Nikola Jokić   C  DEN  74  2004  1019.0  584
# 17966    13792    1994   Hakeem Olajuwon   C  HOU  80  2184   955.0  287
# 26231     5229    1973     Artis Gilmore   C  KEN  84  1743  1476.0  295
#
#          stl    blk   x3p  fg_percent  ft_percent    tov     score
# 536    108.0   68.0  83.0       0.583       0.817  237.0  3792.400
# ...

# %%
guardb = best_szn[best_szn['pos'].isin(['PG', 'SG'])]
forwardb = best_szn[best_szn['pos'].isin(['SF', 'PF'])]
centerb = best_szn[best_szn['pos'].isin(['C'])]

# %%
guardb.head(10)
# Out:
#        seas_id  season                   player pos   tm   g   pts    trb  \
# 5443     26815    2017        Russell Westbrook  PG  OKC  81  2558  864.0
# 3872     27871    2019             James Harden  PG  HOU  78  2818  518.0
# 20354    11647    1989           Michael Jordan  SG  CHI  81  2633  652.0
# 457      31593    2024              Luka Dončić  PG  DAL  70  2370  647.0
# 11708    20200    2006              Kobe Bryant  SG  LAL  80  2832  425.0
# 6062     26260    2016            Stephen Curry  PG  GSW  79  2375  430.0
# 9901     21760    2009              Dwyane Wade  SG  MIA  79  2386  398.0
# 13592    18699    2003            Tracy McGrady  SG  ORL  75  2407  488.0
# 14857    16910    2000              Gary Payton  PG  SEA  82  1982  529.0
# 633      31769    2024  Shai Gilgeous-Alexander  PG  OKC  75  2254  415.0
#
#        ast    stl    blk    x3p  fg_percent  ft_percent    tov     score
# 5443   840  132.0   31.0  200.0       0.425       0.845  438.0  4188.270
# ...

# %%
forwardb.head(10)
# Out:
#        seas_id  season                 player pos   tm   g   pts     trb  ast  \
# 25197     6727    1976          Julius Erving  SF  NYA  84  2462   925.0  423
# 25541     6220    1975        George McGinnis  PF  INA  79  2353  1126.0  495
# 7122     24828    2014           Kevin Durant  SF  OKC  81  2593   598.0  445
# 21889    10015    1985             Larry Bird  SF  BOS  80  2295   842.0  531
# 4692     27322    2018           LeBron James  PF  CLE  82  2251   709.0  747
# 12862    19036    2004          Kevin Garnett  PF  MIN  82  1987  1139.0  409
# 19825    12015    1990            Karl Malone  PF  UTA  82  2540   911.0  226
# 230      31366    2024  Giannis Antetokounmpo  PF  MIL  73  2222   841.0  476
# 14072    18196    2002             Tim Duncan  PF  SAS  82  2089  1042.0  307
# 20562    10991    1988        Charles Barkley  PF  PHI  80  2264   951.0  254
#
#          stl    blk    x3p  fg_percent  ft_percent    tov     score
# ...

# %%
centerb.head(10)
# Out:
#        seas_id  season               player pos   tm   g   pts     trb  ast  \
# 536      31672    2024         Nikola Jokić   C  DEN  79  2085   976.0  708
# 17891    13717    1994       David Robinson   C  SAS  80  2383   855.0  381
# 15089    17142    2000     Shaquille O'Neal   C  LAL  79  2344  1078.0  299
# 23054     8978    1982         Moses Malone   C  HOU  81  2520  1188.0  142
# 18430    13326    1993      Hakeem Olajuwon   C  HOU  82  2140  1068.0  291
# 26231     5229    1973        Artis Gilmore   C  KEN  84  1743  1476.0  295
# 19926    12116    1990        Patrick Ewing   C  NYK  82  2347   893.0  182
# 23710     8178    1980  Kareem Abdul-Jabbar   C  LAL  82  2034   886.0  371
# 5269     26640    2017   Karl-Anthony Towns   C  MIN  82  2061  1007.0  220
# 184      31320    2024     Domantas Sabonis   C  SAC  82  1593  1120.0  673
#
#          stl    blk    x3p  fg_percent  ft_percent    tov     score
# ...

# %%
perg_g = guardb.copy()
perg_f = forwardb.copy()
perg_c = centerb.copy()

# %%
perg_g['ppg'] = perg_g['pts'] / perg_g['g']
perg_g['rpg'] = perg_g['trb'] / perg_g['g']
perg_g['apg'] = perg_g['ast'] / perg_g['g']
perg_g['spg'] = perg_g['stl'] / perg_g['g']
perg_g['bpg'] = perg_g['blk'] / perg_g['g']
perg_g['3pg'] = perg_g['x3p'] / perg_g['g']
perg_g['tpg'] = perg_g['tov'] / perg_g['g']
perg_g.head(10)
# Out:
#        seas_id  season                   player pos   tm   g   pts    trb  \
# 5443     26815    2017        Russell Westbrook  PG  OKC  81  2558  864.0
# 3872     27871    2019             James Harden  PG  HOU  78  2818  518.0
# 20354    11647    1989           Michael Jordan  SG  CHI  81  2633  652.0
# 457      31593    2024              Luka Dončić  PG  DAL  70  2370  647.0
# 11708    20200    2006              Kobe Bryant  SG  LAL  80  2832  425.0
# 6062     26260    2016            Stephen Curry  PG  GSW  79  2375  430.0
# 9901     21760    2009              Dwyane Wade  SG  MIA  79  2386  398.0
# 13592    18699    2003            Tracy McGrady  SG  ORL  75  2407  488.0
# 14857    16910    2000              Gary Payton  PG  SEA  82  1982  529.0
# 633      31769    2024  Shai Gilgeous-Alexander  PG  OKC  75  2254  415.0
#
#        ast    stl  ...  ft_percent    tov     score        ppg        rpg  \
# 5443   840  132.0  ...       0.845  438.0  4188.270  31.580247  10.666667
# ...

# %%
perg_f['ppg'] = perg_f['pts'] / perg_f['g']
perg_f['rpg'] = perg_f['trb'] / perg_f['g']
perg_f['apg'] = perg_f['ast'] / perg_f['g']
perg_f['spg'] = perg_f['stl'] / perg_f['g']
perg_f['bpg'] = perg_f['blk'] / perg_f['g']
perg_f['3pg'] = perg_f['x3p'] / perg_f['g']
perg_f['tpg'] = perg_f['tov'] / perg_f['g']
perg_f.head(10)
# Out:
#        seas_id  season                 player pos   tm   g   pts     trb  ast  \
# 25197     6727    1976          Julius Erving  SF  NYA  84  2462   925.0  423
# 25541     6220    1975        George McGinnis  PF  INA  79  2353  1126.0  495
# 7122     24828    2014           Kevin Durant  SF  OKC  81  2593   598.0  445
# 21889    10015    1985             Larry Bird  SF  BOS  80  2295   842.0  531
# 4692     27322    2018           LeBron James  PF  CLE  82  2251   709.0  747
# 12862    19036    2004          Kevin Garnett  PF  MIN  82  1987  1139.0  409
# 19825    12015    1990            Karl Malone  PF  UTA  82  2540   911.0  226
# 230      31366    2024  Giannis Antetokounmpo  PF  MIL  73  2222   841.0  476
# 14072    18196    2002             Tim Duncan  PF  SAS  82  2089  1042.0  307
# 20562    10991    1988        Charles Barkley  PF  PHI  80  2264   951.0  254
#
#          stl  ...  ft_percent    tov     score        ppg        rpg  \
# ...

# %%
perg_c['ppg'] = perg_c['pts'] / perg_c['g']
perg_c['rpg'] = perg_c['trb'] / perg_c['g']
perg_c['apg'] = perg_c['ast'] / perg_c['g']
perg_c['spg'] = perg_c['stl'] / perg_c['g']
perg_c['bpg'] = perg_c['blk'] / perg_c['g']
perg_c['3pg'] = perg_c['x3p'] / perg_c['g']
perg_c['tpg'] = perg_c['tov'] / perg_c['g']
perg_c.head(10)
# Out:
#        seas_id  season               player pos   tm   g   pts     trb  ast  \
# 536      31672    2024         Nikola Jokić   C  DEN  79  2085   976.0  708
# 17891    13717    1994       David Robinson   C  SAS  80  2383   855.0  381
# 15089    17142    2000     Shaquille O'Neal   C  LAL  79  2344  1078.0  299
# 23054     8978    1982         Moses Malone   C  HOU  81  2520  1188.0  142
# 18430    13326    1993      Hakeem Olajuwon   C  HOU  82  2140  1068.0  291
# 26231     5229    1973        Artis Gilmore   C  KEN  84  1743  1476.0  295
# 19926    12116    1990        Patrick Ewing   C  NYK  82  2347   893.0  182
# 23710     8178    1980  Kareem Abdul-Jabbar   C  LAL  82  2034   886.0  371
# 5269     26640    2017   Karl-Anthony Towns   C  MIN  82  2061  1007.0  220
# 184      31320    2024     Domantas Sabonis   C  SAC  82  1593  1120.0  673
#
#          stl  ...  ft_percent    tov     score        ppg        rpg  \
# ...
